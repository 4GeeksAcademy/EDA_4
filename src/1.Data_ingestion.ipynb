# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv"

df = pd.read_csv(url)
df.to_csv("/workspaces/EDA_4/data/raw/demographic_health_data.csv")

print(df.columns)
# Out:
# Index(['fips', 'TOT_POP', '0-9', '0-9 y/o % of total pop', '19-Oct',
#        '10-19 y/o % of total pop', '20-29', '20-29 y/o % of total pop',
#        '30-39', '30-39 y/o % of total pop',
#        ...
#        'COPD_number', 'diabetes_prevalence', 'diabetes_Lower 95% CI',
#        'diabetes_Upper 95% CI', 'diabetes_number', 'CKD_prevalence',
#        'CKD_Lower 95% CI', 'CKD_Upper 95% CI', 'CKD_number',
#        'Urban_rural_code'],
#       dtype='object', length=108)

# %%
valores_nulos = df.isnull().sum()
valores_nulos.to_csv("/workspaces/EDA_4/data/interim/nulls.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 108 entries, fips to Urban_rural_code
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB

# %%
len(df.drop_duplicates().sum())

columns = ["Median_Household_Income_2018", "Percent of Population Aged 60+", "STATE_NAME", "anycondition_prevalence", "Obesity_prevalence", "Heart disease_prevalence",  "COPD_prevalence", "diabetes_prevalence", "CKD_prevalence"]

# %%
total_data = df[columns]
total_data
# Out:
#       Median_Household_Income_2018  Percent of Population Aged 60+ STATE_NAME  \
# 0                            59338                            19.1    Alabama
# 1                            57588                            26.3    Alabama
# 2                            34382                            23.5    Alabama
# 3                            46064                            21.1    Alabama
# 4                            50412                            23.6    Alabama
# ...                            ...                             ...        ...
# 3135                         73315                            15.8    Wyoming
# 3136                         99087                            18.7    Wyoming
# 3137                         63401                            17.1    Wyoming
# 3138                         55190                            26.7    Wyoming
# 3139                         54319                            29.1    Wyoming
#
# ...

# %%
total_data_gropued = total_data.groupby("STATE_NAME").mean()
total_data_gropued = total_data_gropued.reset_index()
total_data_gropued
# Out:
#               STATE_NAME  Median_Household_Income_2018  \
# 0                Alabama                  43479.820896
# 1                 Alaska                  64079.000000
# 2                Arizona                  49105.866667
# 3               Arkansas                  41801.373333
# 4             California                  67098.655172
# 5               Colorado                  59599.671875
# 6            Connecticut                  77438.625000
# 7               Delaware                  61454.333333
# 8   District of Columbia                  82533.000000
# 9                Florida                  50621.104478
# 10               Georgia                  47507.081761
# 11                Hawaii                  58512.400000
# 12                 Idaho                  52215.750000
# 13              Illinois                  56225.823529
# 14               Indiana                  56036.184783
# 15                  Iowa                  57229.626263
# ...

# %%
total_data_gropued.to_csv('/workspaces/EDA_4/data/processed/conditions_per_state.csv', index= False)
